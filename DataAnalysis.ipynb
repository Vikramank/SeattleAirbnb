# %% [markdown]
# # Airbnb Seattle Dataset
#
# In this notebook I will implement CRISP DM framework on the Airbnb-Seattle dataset to achieve desired outcome.

# %% [markdown]
# ## Business Data understaning
#
# In the following cells, I will overview the given data and frame questions of interest

# %%
import glob, os
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib.pyplot import imread, imshow
files = glob.glob("*.csv")
print("List of files in the given dataset are", end =" ")
print(", ".join(files))
listings = pd.read_csv("listings.csv")
calendar = pd.read_csv("calendar.csv")
reviews  = pd.read_csv("reviews.csv")
# Out:
# List of files in the given dataset are calendar.csv, listings.csv, reviews.csv

# %%
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
print("listings file has {} columns, calendar file has {} columns and reviews file has {} coloums".format(listings.shape[1], calendar.shape[1],reviews.shape[1]))
# Out:
# listings file has 92 columns, calendar file has 4 columns and reviews file has 6 coloums

# %% [markdown]
# ## Files
# * listings file has a detailed description of a rental
# * Calendar file has details about availability and price
# * Review file contains reviews submitted by guests

# %% [markdown]
# ## Business understaning
# I would analyse the given dataset to find answers to the following Business questions:
#
# * What are the available options to stay in Seattle ?
# * What are some of characteristics of hosts?
# * What factors plays a vital role in determining the price?

# %% [markdown]
# ## Data preparation
# Multiple columns from listings.csv and calendar.csv file have insights
# to find answers to the questions of interest.
# ### Dealing with empty values
# * I have removed all the columns with more than 75% empty values.
# * In this analysis, I am not creating an Machine learning model. Hence I didn't replace null values with standard operations like mean/median replacement.
# ### Discarding non-essential columns
# * I have removed all the columns with more than 75% empty values.
# * Additionally I removed columns that contain urls and ids
#
# ### Adding in more features
# * I added few more features like month and day to help understand the trend

# %% [markdown]
# ## Modeling
# I used statistical analysis to analyse columns and find answers. The notebooks EDA_listings and EDA_calendar

# %% [markdown]
# ## Evaluation
# In the following cells, I plot select data that are important to determine the answers

# %%
plt.figure(dpi= 300)
imshow(imread("ReviewRating.jpg"))
plt.axis('off')
plt.show()

# %%
plt.figure(dpi= 300)
imshow(imread("CleanlinessPrice.jpg"))
plt.axis('off')
plt.show()

# %%
plt.figure(dpi= 300)
plt.title("RoomType")
imshow(imread("RoomType.jpg"))
plt.axis('off')
plt.show()

# %%
plt.figure(dpi= 300)
imshow(imread("ResponseTimenormalhosts.jpg"))
plt.axis('off')
plt.show()

# %%
plt.figure(dpi= 300)
imshow(imread("ResponseTimeSuperhosts.jpg"))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Deployment
# * The data analysis in this project will be of great use for home owners and visitors in Seattle.
# * The trend is likely to change due to pandemic. Hence making similar analysis with recent dataset will provide more insight.

# %% [markdown]
# ## Conclusion
# * Property type, room type, neighborhood, cleanliness and ratings play a vital role in determining the price.
# * As a host, to boost your income follow best practices by super hosts and check out points discussed in third section that influence the price.
# * As a visitor AirBnB in Seattle offers a wide range of staying options catering to different budgets and requirements in different neighbourhoods.
